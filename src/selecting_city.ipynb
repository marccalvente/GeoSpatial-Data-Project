# %%
import os
import requests
import json

from dotenv import load_dotenv
import pandas as pd
import numpy as np

from pymongo import MongoClient
from pymongo import GEOSPHERE

# %% [markdown]
# ## Load token

# %%
load_dotenv()
# Out:
# True

# %%
token_fsq = os.getenv("foursquare_token")

# %% [markdown]
# ## Connection to MongoDB to check companies

# %%
client = MongoClient("localhost:27017")

# %%
db = client.get_database("ironhack")

# %%
c = db.get_collection("companies")

# %%
# Para filtrar la mongodb
condition_money = {"total_money_raised": {"$regex": '[$|€].*[M|B]'}}
condition_gaming = {"category_code": {"$regex": "[.*]?game[.*]?"}}
condition_design = {"tag_list": {"$regex": "[.*]?design[.*]?"}}
condition_money_gaming = [condition_money, condition_gaming]

projection = {"_id": 0, "name": 1,"total_money_raised": 1, "offices": 1}

# %%
companies_df = list(c.find({"$or": 
                 [{"$and": condition_money_gaming}, condition_design]}, 
                    projection))

# %%
companies_df = pd.DataFrame(companies_df)

# %%
companies_df = companies_df.explode("offices")

# %%
companies_df = pd.concat([companies_df, companies_df["offices"].apply(pd.Series)[["city", "country_code", "latitude", "longitude"]]], axis=1)

# %%
companies_df.drop("offices", axis=1, inplace=True)

# %%
def return_money(value):
    """ input: a string containing the money rised by a company
        output: a float with the money properly formated turning M to milions and B to billions
    """
    if value.startswith("$") or value.startswith("€"):
        if value.endswith("k"):
            return round(float(value[1:-1])*100)
        elif value.endswith("M"):
            return round(float(value[1:-1])*100000)
        elif value.endswith("B"):
            return round(float(value[1:-1])*100000000)
        else:
            return 0

# %%
companies_df["total_money_raised"] = companies_df["total_money_raised"].apply(return_money)

# %%
companies_df["city"].replace(to_replace="", value=np.nan, inplace=True)

# %%
companies_df["city"].value_counts(dropna=True).head(10)
# Out:
# San Francisco    62
# New York         53
# London           32
# Los Angeles      21
# Palo Alto        13
# San Diego        13
# Paris            13
# Santa Monica     11
# Seattle          11
# Bangalore        11
# Name: city, dtype: int64

# %%
companies_df.groupby("city").sum()["total_money_raised"].sort_values(ascending=False)
# Out:
# city
# San Francisco     254178000.0
# Los Angeles       111248000.0
# Baltimore          86000000.0
# New York           76653000.0
# Philadelphia       72500000.0
#                      ...
# Idukki                    0.0
# Hyderabad                 0.0
# Hove                      0.0
# Houston                   0.0
# virginia beach            0.0
# Name: total_money_raised, Length: 453, dtype: float64

# %% [markdown]
# ### Since both San Francisco and New York appear in the top of the list of cities with more design companies and with more gaming companies with higher total money raised we will investigate those 2.

# %%
san_fancisco_companies = companies_df[companies_df["city"] == "San Francisco"].dropna(axis=0, subset=["latitude", "longitude"])

# %%
new_york_companies = companies_df[companies_df["city"] == "New York"].dropna(axis=0, subset=["latitude", "longitude"])

# %%
san_fancisco_companies.to_csv("../data/san_francisco_companies.csv", index=False)
new_york_companies.to_csv("../data/new_york_companies.csv", index=False)

# %%
san_fancisco_companies
# Out:
#                               name  total_money_raised           city  \
# 0                             Digg           4500000.0  San Francisco
# 4                             Kyte           2340000.0  San Francisco
# 9                          Ustream           6010000.0  San Francisco
# 12                       Revision3            900000.0  San Francisco
# 13                          CastTV            310000.0  San Francisco
# 19                             hi5           5200000.0  San Francisco
# 20                           Curse           1200000.0  San Francisco
# 31                        Metacafe           5000000.0  San Francisco
# 34                      Kongregate           1900000.0  San Francisco
# 35                        DanceJam            450000.0  San Francisco
# 38                           Mevio           4890000.0  San Francisco
# 46                     Crunchyroll            480000.0  San Francisco
# 61                         Rupture            300000.0  San Francisco
# 80                       PlayFirst           3770000.0  San Francisco
# 84                        Outspark           2330000.0  San Francisco
# 86                           Zynga          86000000.0  San Francisco
# 106                      99designs           3500000.0  San Francisco
# 143                      Cutcaster                 0.0  San Francisco
# 151               Serious Business            400000.0  San Francisco
# 154                          Kabam          12500000.0  San Francisco
# 159                 Citizen Sports           1000000.0  San Francisco
# 176                       PurePlay           1500000.0  San Francisco
# 259                           Lexy            171000.0  San Francisco
# 264                         Minted           5270000.0  San Francisco
# 289                         ngmoco           4480000.0  San Francisco
# 307                        Ecolect                 0.0  San Francisco
# 318  Shattered Reality Interactive            110000.0  San Francisco
# 323                         Popego                 0.0  San Francisco
# 331                        Milobox                 0.0  San Francisco
# 344                        Ecolect                 0.0  San Francisco
# 355  Shattered Reality Interactive            110000.0  San Francisco
# 360                         Popego                 0.0  San Francisco
# 368                        Milobox                 0.0  San Francisco
# 385                    Brightstorm            600000.0  San Francisco
# 412                     One Season            375000.0  San Francisco
# 428                         Booyah           5950000.0  San Francisco
# 431                        GotGame            100000.0  San Francisco
# 584                         Heyzap            797000.0  San Francisco
# 679             Unity Technologies           1750000.0  San Francisco
# 767                   Bamboudesign                 0.0  San Francisco
# 787                    Netbiscuits           2700000.0  San Francisco
# 887                          Exent            300000.0  San Francisco
#
#     country_code   latitude   longitude
# 0            USA  37.764726 -122.394523
# 4            USA  37.788482 -122.409173
# 9            USA  37.392936 -122.079480
# 12           USA  37.757758 -122.388243
# 13           USA  37.780716 -122.393913
# 19           USA  37.788668 -122.400558
# 20           USA  37.787092 -122.399972
# 31           USA  37.437328 -122.159928
# 34           USA  37.786942 -122.401245
# 35           USA  37.781557 -122.407959
# 38           USA  37.782263 -122.392142
# 46           USA  37.781265 -122.393229
# 61           USA  37.783898 -122.395234
# 80           USA  37.790346 -122.401850
# 84           USA  37.775196 -122.419204
# 86           USA  37.765158 -122.404234
# 106          USA  37.795531 -122.400598
# 143          USA  37.798510 -122.457454
# 151          USA  37.789321 -122.401362
# 154          USA  37.394456 -122.078531
# 159          USA  37.777513 -122.397044
# 176          USA  37.775196 -122.419204
# 259          USA  37.786906 -122.397672
# 264          USA  37.797435 -122.403175
# 289          USA  37.770510 -122.401581
# 307          USA  37.776769 -122.410111
# 318          USA  37.783046 -122.394067
# 323          USA  37.778687 -122.421242
# 331          USA  37.792979 -122.421242
# 344          USA  37.776769 -122.410111
# 355          USA  37.783046 -122.394067
# 360          USA  37.778687 -122.421242
# 368          USA  37.792979 -122.421242
# 385          USA  37.804619 -122.371203
# 412          USA  37.775196 -122.419204
# 428          USA  37.420728 -122.210341
# 431          USA  37.777720 -122.395785
# 584          USA  37.790554 -122.404149
# 679          USA  55.692461   12.530107
# 767          USA  37.775087 -122.415199
# 787          USA  37.755037 -122.426442
# 887          USA  37.787646 -122.402759
